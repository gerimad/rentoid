# %%
import pandas as pd

# %%
import json
import ast
df = pd.read_csv('db.csv', converters={'extra': ast.literal_eval})

# %%
df.describe()
# Out:
#         Unnamed: 0
# count  1214.000000
# mean    606.500000
# std     350.595921
# min       0.000000
# 25%     303.250000
# 50%     606.500000
# 75%     909.750000
# max    1213.000000

# %%
df['extra'].iloc[0]
# Out:
# {'Épület típusa': 'Lakás',
#  'Közös költség': '18 000 Ft/hó',
#  'Fűtés': 'Házközp. mérőórával',
#  'Minimum bérlési idő': 'Legalább 1 év',
#  'Berendezés': 'Berendezett, gépesített',
#  'Emelet': '4',
#  'Lift': 'Van',
#  'Kilátás': 'Utcai',
#  'Erkélyek száma': '1',
#  'Min. bérlési idő': 'Legalább 1 év',
#  'Energiatanúsítvány': 'Nem adott',
#  'Ház jellege': '2000 után épült (Újszerű)',
#  'Ingatlan állapota': 'Kiváló',
#  'Komfort fokozat': 'Összkomfortos',
#  'Parkolási lehetőség': 'Fizetős parkoló övezet',
#  'Épület szintjei': '9'}

# %%
print(df['extra'].iloc[0])
print(df['link'].iloc[0])
#extras = {key: value for key, value in }
# Out:
# {'Épület típusa': 'Lakás', 'Közös költség': '18 000 Ft/hó', 'Fűtés': 'Házközp. mérőórával', 'Minimum bérlési idő': 'Legalább 1 év', 'Berendezés': 'Berendezett, gépesített', 'Emelet': '4', 'Lift': 'Van', 'Kilátás': 'Utcai', 'Erkélyek száma': '1', 'Min. bérlési idő': 'Legalább 1 év', 'Energiatanúsítvány': 'Nem adott', 'Ház jellege': '2000 után épült (Újszerű)', 'Ingatlan állapota': 'Kiváló', 'Komfort fokozat': 'Összkomfortos', 'Parkolási lehetőség': 'Fizetős parkoló övezet', 'Épület szintjei': '9'}
# https://www.alberlet.hu/kiado_alberlet/budapest-XIV-kerulet-chazar-andras-utca-58m2-3-szoba_744597

# %%
features = set()
for line in df['extra'].values:
    #print(type(line))
    for _, (k, v) in enumerate(line.items()):
        if k not in features:
            features.add(k)

features
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# ...

# %%
len(features)
# Out:
# 39

# %%
print(features)
# Out:
# {'Energiatanúsítvány', 'Belmagasság', 'Dohányzás', 'Épület típusa', 'Különnyíló szoba', 'Társasház neve', 'Konyhai szellőzés', 'Min. bérlési idő', 'Minimum bérlési idő', 'Melegvíz', 'Kisállat', 'Kilátás', 'Beköltözhető', 'Közös költség', 'Fűtés', 'Ingatlan állapota', 'Kábeltévé szolgáltató', 'Amerikai konyha', 'Emelet', 'Rezsi költség', 'Gyermekbarát', 'Épület szintjei', 'Parkolási lehetőség', 'Hónapokra is', 'Építés éve', 'Komfort fokozat', 'Kaució', 'Erkélyek száma', 'Bérleti díj hónapokra', 'Hall', 'Berendezés', 'Ház jellege', 'Diákoknak', 'Városrész', 'Közös költségben', 'Tájolás', 'Kaució hónapokra', 'Lift', 'Mosógép van'}
